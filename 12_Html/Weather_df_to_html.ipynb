# %%
import pandas as pd

# %%
file = "../API_HW/OpenWeatherMap_Data_538_Cities.csv"

weather_df = pd.read_csv(file)

# %%
weather_df.head()
# Out:
#    Unnamed: 0      City,Country  Latitude  Longitude  Temperature  Humidity  \
# 0           1   punta arenas,cl    -53.16     -70.91        46.40      95.0
# 1           2      ketchikan,us     55.34    -131.65        30.04      48.0
# 2           3  pacific grove,us     36.62    -121.92        51.91      77.0
# 3           4   puerto ayora,ec     -0.74     -90.35        82.40      65.0
# 4           5      cape town,za    -33.93      18.42        64.40      82.0
#
#    Cloudiness  Wind Speed (mph)
# 0        40.0             14.99
# 1         1.0             16.11
# 2        90.0             17.22
# 3        20.0             16.11
# 4         0.0              8.05

# %%
weather_df = weather_df.drop(columns=['Unnamed: 0'])
weather_df.head()
# Out:
#           City,Country  Latitude  Longitude  Temperature  Humidity  \
# 0      punta arenas,cl    -53.16     -70.91        46.40      95.0
# 1         ketchikan,us     55.34    -131.65        30.04      48.0
# 2     pacific grove,us     36.62    -121.92        51.91      77.0
# 3      puerto ayora,ec     -0.74     -90.35        82.40      65.0
# 4         cape town,za    -33.93      18.42        64.40      82.0
# 5              mitu,co      1.20     -70.17        72.60      99.0
# 6         busselton,au    -33.64     115.35        68.42      98.0
# 7     manuk mangkaw,ph      4.80     119.85        83.18     100.0
# 8           rikitea,pf    -23.12    -134.97        77.60     100.0
# 9         upernavik,gl     72.79     -56.15         3.12     100.0
# 10           atuona,pf     -9.80    -139.03        79.67     100.0
# 11       kaitangata,nz    -46.28     169.85        66.93      65.0
# 12          bristol,us     41.68     -71.27        36.32      58.0
# ...

# %%
weather_df.to_html()
# Out:
# '<table border="1" class="dataframe">\n  <thead>\n    <tr style="text-align: right;">\n      <th></th>\n      <th>City,Country</th>\n      <th>Latitude</th>\n      <th>Longitude</th>\n      <th>Temperature</th>\n      <th>Humidity</th>\n      <th>Cloudiness</th>\n      <th>Wind Speed (mph)</th>\n    </tr>\n  </thead>\n  <tbody>\n    <tr>\n      <th>0</th>\n      <td>punta arenas,cl</td>\n      <td>-53.16</td>\n      <td>-70.91</td>\n      <td>46.40</td>\n      <td>95.0</td>\n      <td>40.0</td>\n      <td>14.99</td>\n    </tr>\n    <tr>\n      <th>1</th>\n      <td>ketchikan,us</td>\n      <td>55.34</td>\n      <td>-131.65</td>\n      <td>30.04</td>\n      <td>48.0</td>\n      <td>1.0</td>\n      <td>16.11</td>\n    </tr>\n    <tr>\n      <th>2</th>\n      <td>pacific grove,us</td>\n      <td>36.62</td>\n      <td>-121.92</td>\n      <td>51.91</td>\n      <td>77.0</td>\n      <td>90.0</td>\n      <td>17.22</td>\n    </tr>\n    <tr>\n      <th>3</th>\n      <td>puerto ayora,ec</td>\n 
# ...
